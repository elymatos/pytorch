# %%
import json
import random
import re
from itertools import product

# === CONFIGURAÇÃO ===
MODEL_FILE = "htpc_model.json"
MULTIWORDS_FILE = "multiwords.txt"
TEST_SENTENCE = "O homem, que estava cansado, preparou o café da manhã com cuidado."
NOISE_PROBABILITY = 0.0

# === MULTIWORDS ===
def load_multiwords(path):
    multiwords = []
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            mw = line.strip().lower()
            if mw:
                multiwords.append((mw, mw.replace(" ", "_")))
    return multiwords

def replace_multiwords(text, multiword_list):
    for original, replacement in multiword_list:
        text = text.replace(original, replacement)
    return text

# === TOKENIZAÇÃO ===
def normalize_token(token):
    return re.sub(r"[.,!?;:()\\[\\]{}\\\"']", "", token.lower())

def tokenize(sentence):
    return [normalize_token(tok) for tok in sentence.strip().split() if tok]

# === MODELO HTPC ===
def load_model(json_path):
    with open(json_path, "r", encoding="utf-8") as f:
        model = json.load(f)

    token_transitions = model['token_transitions']
    bigram_memory = {
        tuple(key.split("|||")): value
        for key, value in model['bigram_memory'].items()
    }
    phrase_memory = {
        tuple(tuple(pair.split("__")) for pair in key.split("|||")): value
        for key, value in model['phrase_memory'].items()
    }
    phrase_hierarchy = model.get('phrase_hierarchy', {})
    return token_transitions, bigram_memory, phrase_memory, phrase_hierarchy

# === MEMÓRIA DE CONTEXTO ===
class ContextBuffer:
    def __init__(self):
        self.buffer = {}

    def add(self, key, value):
        """Add a token to the buffer."""
        self.buffer[key] = value

    def get(self, key):
        """Retrieve a token from the buffer."""
        return self.buffer.get(key, None)

    def clear(self):
        """Clear the buffer."""
        self.buffer.clear()

# Instanciar a memória
context_buffer = ContextBuffer()

# === REMAPEAMENTO TOP-DOWN ===
def dynamic_feedback_for_context(context_tokens, phrase_memory, phrase_hierarchy, noise_probability=0.0):
    expectations = set()
    for phrase in phrase_memory:
        flat = [phrase[0][0]] + [pair[1] for pair in phrase]
        for i in range(len(flat) - 1):
            match_len = i + 1
            if flat[:match_len] == context_tokens[-match_len:]:
                next_token = flat[i + 1]
                if random.random() > noise_probability:
                    expectations.add(next_token)

        # nível 2
        if phrase in phrase_hierarchy:
            for _, seq in phrase_hierarchy[phrase]:
                for i in range(len(seq) - 1):
                    match_len = i + 1
                    if seq[:match_len] == context_tokens[-match_len:]:
                        next_token = seq[i + 1]
                        if random.random() > noise_probability:
                            expectations.add(next_token)
    return expectations

# === COMPARA FRASES ===
def match_all_phrases(tokens, phrase_memory):
    matched_phrases = []
    n = len(tokens)
    for phrase in phrase_memory:
        phrase_len = len(phrase) + 1
        for i in range(n - phrase_len + 1):
            test_bigrams = tuple((tokens[j], tokens[j + 1]) for j in range(i, i + phrase_len - 1))
            if test_bigrams == phrase:
                phrase_str = " ".join([tokens[i]] + [tokens[i + k + 1] for k in range(len(phrase))])
                matched_phrases.append(phrase_str)
    return matched_phrases

# === RECONHECIMENTO ===
def recognize_patterns(tokens, token_transitions, bigram_memory, phrase_memory, phrase_hierarchy, noise_probability=0.0):
    patterns = []
    current_pattern = []

    for i in range(len(tokens)):
        curr_token = tokens[i]
        prev_token = tokens[i - 1] if i > 0 else None

        # Armazenar sujeitos no buffer
        if curr_token in ['I', 'he', 'she', 'they']:  # Exemplo simplificado de sujeitos
            context_buffer.add('subject', curr_token)

        # Exemplo de verbos
        if curr_token in ['have', 'is', 'am']:  # Simplificação para verbos
            subject = context_buffer.get('subject')
            if subject:
                print(f"🔗 Ligando {subject} com o verbo {curr_token}")

        is_valid_transition = (
            token_transitions.get(prev_token) == curr_token or
            (prev_token, curr_token) in bigram_memory
        )

        context = current_pattern[-3:]
        dynamic_expectations = dynamic_feedback_for_context(context, phrase_memory, phrase_hierarchy, noise_probability)
        top_down_match = curr_token in dynamic_expectations

        print(f"🔎 Token atual: '{curr_token}' | Precedente: '{prev_token}'")
        print(f"   → Transição válida? {is_valid_transition}")
        print(f"   → Expectativas top-down: {dynamic_expectations} → Compatível? {top_down_match}")

        if is_valid_transition and top_down_match:
            current_pattern.append(curr_token)
        else:
            print(f"\n⚠️  Inibição em '{curr_token}' (posição {i})")
            if len(current_pattern) > 1:
                matched_phrases = match_all_phrases(current_pattern, phrase_memory)
                print(f"   ✔️ Frase encerrada: {' '.join(current_pattern)}")
                patterns.append((current_pattern.copy(), matched_phrases))
            current_pattern = [curr_token]

    if len(current_pattern) > 1:
        matched_phrases = match_all_phrases(current_pattern, phrase_memory)
        patterns.append((current_pattern, matched_phrases))

    # Verificar frases compostas (nível 2) usando a hierarquia
    for base_key, continuations in phrase_hierarchy.items():
        for continuation in continuations:
            print(f"🔍 Frase composta reconhecida: {base_key} → {continuation}")
            patterns.append((base_key, [continuation]))

    return patterns

# === EXECUÇÃO ===
if __name__ == "__main__":
    random.seed(42)
    multiwords = load_multiwords(MULTIWORDS_FILE)
    sentence = replace_multiwords(TEST_SENTENCE.lower(), multiwords)
    tokens = tokenize(sentence)

    print("\n📌 Tokens gerados da sentença de teste:")
    print(tokens)

    token_transitions, bigram_memory, phrase_memory, phrase_hierarchy = load_model(MODEL_FILE)

    print("\n🧠 Reconhecimento HTPC com remapeamento dinâmico (ruído={NOISE_PROBABILITY})")
    patterns = recognize_patterns(tokens, token_transitions, bigram_memory, phrase_memory, phrase_hierarchy, NOISE_PROBABILITY)

    print("\n🔍 Padrões Reconhecidos:")
    for idx, (tokens, phrases) in enumerate(patterns, 1):
        print(f"\n  Padrão {idx}:")
        print(f"    Tokens: {' '.join(tokens)}")
        if phrases:
            print("    Frases correspondentes:")
            for p in phrases:
                print(f"      • {p}")
        else:
            print("    Frases correspondentes: (nenhuma)")
# Out:
# 📌 Tokens gerados da sentença de teste:
# ['o', 'homem', 'preparou', 'o', 'café_da_manhã', 'com', 'cuidado']
#
# 🧠 Reconhecimento HTPC com remapeamento dinâmico (ruído={NOISE_PROBABILITY})
# 🔎 Token atual: 'o' | Precedente: 'None'
#    → Transição válida? False
#    → Expectativas top-down: set() → Compatível? False
#
# ⚠️  Inibição em 'o' (posição 0)
# 🔎 Token atual: 'homem' | Precedente: 'o'
#    → Transição válida? True
#    → Expectativas top-down: {'grupo', 'homem', 'cachorro', 'café_da_manhã'} → Compatível? True
# 🔎 Token atual: 'preparou' | Precedente: 'homem'
#    → Transição válida? True
#    → Expectativas top-down: {'preparou'} → Compatível? True
# 🔎 Token atual: 'o' | Precedente: 'preparou'
#    → Transição válida? True
#    → Expectativas top-down: {'o'} → Compatível? True
# 🔎 Token atual: 'café_da_manhã' | Precedente: 'o'
#    → Transição válida? True
#    → Expectativas top-down: {'grupo', 'homem', 'cachorro', 'café_da_manhã'} → Compatível? True
# 🔎 Token atual: 'com' | Precedente: 'café_da_manhã'
#    → Transição válida? True
#    → Expectativas top-down: {'juntos', 'fomos', 'e', 'com'} → Compatível? True
# 🔎 Token atual: 'cuidado' | Precedente: 'com'
#    → Transição válida? True
#    → Expectativas top-down: {'cuidado', 'o'} → Compatível? True
# 🔍 Frase composta reconhecida: a__menina|||menina__estava → a menina estava tomando café_da_manhã
# 🔍 Frase composta reconhecida: menina__estava|||estava__tomando → menina estava tomando café_da_manhã com
# 🔍 Frase composta reconhecida: estava__tomando|||tomando__café_da_manhã → estava tomando café_da_manhã com o
# 🔍 Frase composta reconhecida: estava__tomando|||tomando__café_da_manhã → estava tomando café_da_manhã com cuidado
# 🔍 Frase composta reconhecida: estava__tomando|||tomando__café_da_manhã → estava tomando café_da_manhã fomos caminhar
# 🔍 Frase composta reconhecida: estava__tomando|||tomando__café_da_manhã → estava tomando café_da_manhã e depois
# 🔍 Frase composta reconhecida: tomando__café_da_manhã|||café_da_manhã__com → tomando café_da_manhã com o cachorro
# 🔍 Frase composta reconhecida: café_da_manhã__com|||com__o → café_da_manhã com o cachorro na
# 🔍 Frase composta reconhecida: café_da_manhã__com|||com__o → café_da_manhã com o homem preparou
# 🔍 Frase composta reconhecida: café_da_manhã__com|||com__o → café_da_manhã com o café_da_manhã com
# 🔍 Frase composta reconhecida: café_da_manhã__com|||com__o → café_da_manhã com o café_da_manhã e
# 🔍 Frase composta reconhecida: café_da_manhã__com|||com__o → café_da_manhã com o grupo chegou
# 🔍 Frase composta reconhecida: café_da_manhã__com|||com__o → café_da_manhã com o café_da_manhã juntos
# 🔍 Frase composta reconhecida: com__o|||o__cachorro → com o cachorro na sala
# 🔍 Frase composta reconhecida: o__homem|||homem__preparou → o homem preparou o café_da_manhã
# 🔍 Frase composta reconhecida: homem__preparou|||preparou__o → homem preparou o cachorro na
# 🔍 Frase composta reconhecida: homem__preparou|||preparou__o → homem preparou o homem preparou
# 🔍 Frase composta reconhecida: homem__preparou|||preparou__o → homem preparou o café_da_manhã com
# 🔍 Frase composta reconhecida: homem__preparou|||preparou__o → homem preparou o café_da_manhã e
# 🔍 Frase composta reconhecida: homem__preparou|||preparou__o → homem preparou o grupo chegou
# 🔍 Frase composta reconhecida: homem__preparou|||preparou__o → homem preparou o café_da_manhã juntos
# 🔍 Frase composta reconhecida: preparou__o|||o__café_da_manhã → preparou o café_da_manhã com o
# 🔍 Frase composta reconhecida: preparou__o|||o__café_da_manhã → preparou o café_da_manhã com cuidado
# 🔍 Frase composta reconhecida: preparou__o|||o__café_da_manhã → preparou o café_da_manhã fomos caminhar
# 🔍 Frase composta reconhecida: preparou__o|||o__café_da_manhã → preparou o café_da_manhã e depois
# 🔍 Frase composta reconhecida: o__café_da_manhã|||café_da_manhã__com → o café_da_manhã com o cachorro
# 🔍 Frase composta reconhecida: depois__do|||do__café_da_manhã → depois do café_da_manhã com o
# 🔍 Frase composta reconhecida: depois__do|||do__café_da_manhã → depois do café_da_manhã com cuidado
# 🔍 Frase composta reconhecida: depois__do|||do__café_da_manhã → depois do café_da_manhã fomos caminhar
# 🔍 Frase composta reconhecida: depois__do|||do__café_da_manhã → depois do café_da_manhã e depois
# 🔍 Frase composta reconhecida: do__café_da_manhã|||café_da_manhã__fomos → do café_da_manhã fomos caminhar no
# 🔍 Frase composta reconhecida: café_da_manhã__fomos|||fomos__caminhar → café_da_manhã fomos caminhar no parque
# 🔍 Frase composta reconhecida: a__criança|||criança__tomou → a criança tomou o café_da_manhã
# 🔍 Frase composta reconhecida: criança__tomou|||tomou__o → criança tomou o cachorro na
# 🔍 Frase composta reconhecida: criança__tomou|||tomou__o → criança tomou o homem preparou
# 🔍 Frase composta reconhecida: criança__tomou|||tomou__o → criança tomou o café_da_manhã com
# 🔍 Frase composta reconhecida: criança__tomou|||tomou__o → criança tomou o café_da_manhã e
# 🔍 Frase composta reconhecida: criança__tomou|||tomou__o → criança tomou o grupo chegou
# 🔍 Frase composta reconhecida: criança__tomou|||tomou__o → criança tomou o café_da_manhã juntos
# 🔍 Frase composta reconhecida: tomou__o|||o__café_da_manhã → tomou o café_da_manhã com o
# 🔍 Frase composta reconhecida: tomou__o|||o__café_da_manhã → tomou o café_da_manhã com cuidado
# 🔍 Frase composta reconhecida: tomou__o|||o__café_da_manhã → tomou o café_da_manhã fomos caminhar
# 🔍 Frase composta reconhecida: tomou__o|||o__café_da_manhã → tomou o café_da_manhã e depois
# 🔍 Frase composta reconhecida: o__café_da_manhã|||café_da_manhã__e → o café_da_manhã e depois estudou
# 🔍 Frase composta reconhecida: o__café_da_manhã|||café_da_manhã__e → o café_da_manhã e tomou o
# 🔍 Frase composta reconhecida: café_da_manhã__e|||e__depois → café_da_manhã e depois do café_da_manhã
# 🔍 Frase composta reconhecida: café_da_manhã__e|||e__depois → café_da_manhã e depois estudou matemática
# 🔍 Frase composta reconhecida: o__grupo|||grupo__chegou → o grupo chegou cedo e
# 🔍 Frase composta reconhecida: grupo__chegou|||chegou__cedo → grupo chegou cedo e tomou
# 🔍 Frase composta reconhecida: chegou__cedo|||cedo__e → chegou cedo e depois estudou
# 🔍 Frase composta reconhecida: chegou__cedo|||cedo__e → chegou cedo e tomou o
# 🔍 Frase composta reconhecida: cedo__e|||e__tomou → cedo e tomou o café_da_manhã
# 🔍 Frase composta reconhecida: e__tomou|||tomou__o → e tomou o cachorro na
# 🔍 Frase composta reconhecida: e__tomou|||tomou__o → e tomou o homem preparou
# 🔍 Frase composta reconhecida: e__tomou|||tomou__o → e tomou o café_da_manhã com
# 🔍 Frase composta reconhecida: e__tomou|||tomou__o → e tomou o café_da_manhã e
# 🔍 Frase composta reconhecida: e__tomou|||tomou__o → e tomou o grupo chegou
# 🔍 Frase composta reconhecida: e__tomou|||tomou__o → e tomou o café_da_manhã juntos
#
# 🔍 Padrões Reconhecidos:
#
#   Padrão 1:
#     Tokens: o homem preparou o café_da_manhã com cuidado
#     Frases correspondentes:
#       • o homem preparou
#       • homem preparou o
#       • preparou o café_da_manhã
#       • o café_da_manhã com
#       • café_da_manhã com cuidado
#
#   Padrão 2:
#     Tokens: a _ _ m e n i n a | | | m e n i n a _ _ e s t a v a
#     Frases correspondentes:
#       • a menina estava tomando café_da_manhã
#
#   Padrão 3:
#     Tokens: m e n i n a _ _ e s t a v a | | | e s t a v a _ _ t o m a n d o
#     Frases correspondentes:
#       • menina estava tomando café_da_manhã com
#
#   Padrão 4:
#     Tokens: e s t a v a _ _ t o m a n d o | | | t o m a n d o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • estava tomando café_da_manhã com o
#
#   Padrão 5:
#     Tokens: e s t a v a _ _ t o m a n d o | | | t o m a n d o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • estava tomando café_da_manhã com cuidado
#
#   Padrão 6:
#     Tokens: e s t a v a _ _ t o m a n d o | | | t o m a n d o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • estava tomando café_da_manhã fomos caminhar
#
#   Padrão 7:
#     Tokens: e s t a v a _ _ t o m a n d o | | | t o m a n d o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • estava tomando café_da_manhã e depois
#
#   Padrão 8:
#     Tokens: t o m a n d o _ _ c a f é _ d a _ m a n h ã | | | c a f é _ d a _ m a n h ã _ _ c o m
#     Frases correspondentes:
#       • tomando café_da_manhã com o cachorro
#
#   Padrão 9:
#     Tokens: c a f é _ d a _ m a n h ã _ _ c o m | | | c o m _ _ o
#     Frases correspondentes:
#       • café_da_manhã com o cachorro na
#
#   Padrão 10:
#     Tokens: c a f é _ d a _ m a n h ã _ _ c o m | | | c o m _ _ o
#     Frases correspondentes:
#       • café_da_manhã com o homem preparou
#
#   Padrão 11:
#     Tokens: c a f é _ d a _ m a n h ã _ _ c o m | | | c o m _ _ o
#     Frases correspondentes:
#       • café_da_manhã com o café_da_manhã com
#
#   Padrão 12:
#     Tokens: c a f é _ d a _ m a n h ã _ _ c o m | | | c o m _ _ o
#     Frases correspondentes:
#       • café_da_manhã com o café_da_manhã e
#
#   Padrão 13:
#     Tokens: c a f é _ d a _ m a n h ã _ _ c o m | | | c o m _ _ o
#     Frases correspondentes:
#       • café_da_manhã com o grupo chegou
#
#   Padrão 14:
#     Tokens: c a f é _ d a _ m a n h ã _ _ c o m | | | c o m _ _ o
#     Frases correspondentes:
#       • café_da_manhã com o café_da_manhã juntos
#
#   Padrão 15:
#     Tokens: c o m _ _ o | | | o _ _ c a c h o r r o
#     Frases correspondentes:
#       • com o cachorro na sala
#
#   Padrão 16:
#     Tokens: o _ _ h o m e m | | | h o m e m _ _ p r e p a r o u
#     Frases correspondentes:
#       • o homem preparou o café_da_manhã
#
#   Padrão 17:
#     Tokens: h o m e m _ _ p r e p a r o u | | | p r e p a r o u _ _ o
#     Frases correspondentes:
#       • homem preparou o cachorro na
#
#   Padrão 18:
#     Tokens: h o m e m _ _ p r e p a r o u | | | p r e p a r o u _ _ o
#     Frases correspondentes:
#       • homem preparou o homem preparou
#
#   Padrão 19:
#     Tokens: h o m e m _ _ p r e p a r o u | | | p r e p a r o u _ _ o
#     Frases correspondentes:
#       • homem preparou o café_da_manhã com
#
#   Padrão 20:
#     Tokens: h o m e m _ _ p r e p a r o u | | | p r e p a r o u _ _ o
#     Frases correspondentes:
#       • homem preparou o café_da_manhã e
#
#   Padrão 21:
#     Tokens: h o m e m _ _ p r e p a r o u | | | p r e p a r o u _ _ o
#     Frases correspondentes:
#       • homem preparou o grupo chegou
#
#   Padrão 22:
#     Tokens: h o m e m _ _ p r e p a r o u | | | p r e p a r o u _ _ o
#     Frases correspondentes:
#       • homem preparou o café_da_manhã juntos
#
#   Padrão 23:
#     Tokens: p r e p a r o u _ _ o | | | o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • preparou o café_da_manhã com o
#
#   Padrão 24:
#     Tokens: p r e p a r o u _ _ o | | | o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • preparou o café_da_manhã com cuidado
#
#   Padrão 25:
#     Tokens: p r e p a r o u _ _ o | | | o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • preparou o café_da_manhã fomos caminhar
#
#   Padrão 26:
#     Tokens: p r e p a r o u _ _ o | | | o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • preparou o café_da_manhã e depois
#
#   Padrão 27:
#     Tokens: o _ _ c a f é _ d a _ m a n h ã | | | c a f é _ d a _ m a n h ã _ _ c o m
#     Frases correspondentes:
#       • o café_da_manhã com o cachorro
#
#   Padrão 28:
#     Tokens: d e p o i s _ _ d o | | | d o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • depois do café_da_manhã com o
#
#   Padrão 29:
#     Tokens: d e p o i s _ _ d o | | | d o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • depois do café_da_manhã com cuidado
#
#   Padrão 30:
#     Tokens: d e p o i s _ _ d o | | | d o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • depois do café_da_manhã fomos caminhar
#
#   Padrão 31:
#     Tokens: d e p o i s _ _ d o | | | d o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • depois do café_da_manhã e depois
#
#   Padrão 32:
#     Tokens: d o _ _ c a f é _ d a _ m a n h ã | | | c a f é _ d a _ m a n h ã _ _ f o m o s
#     Frases correspondentes:
#       • do café_da_manhã fomos caminhar no
#
#   Padrão 33:
#     Tokens: c a f é _ d a _ m a n h ã _ _ f o m o s | | | f o m o s _ _ c a m i n h a r
#     Frases correspondentes:
#       • café_da_manhã fomos caminhar no parque
#
#   Padrão 34:
#     Tokens: a _ _ c r i a n ç a | | | c r i a n ç a _ _ t o m o u
#     Frases correspondentes:
#       • a criança tomou o café_da_manhã
#
#   Padrão 35:
#     Tokens: c r i a n ç a _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • criança tomou o cachorro na
#
#   Padrão 36:
#     Tokens: c r i a n ç a _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • criança tomou o homem preparou
#
#   Padrão 37:
#     Tokens: c r i a n ç a _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • criança tomou o café_da_manhã com
#
#   Padrão 38:
#     Tokens: c r i a n ç a _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • criança tomou o café_da_manhã e
#
#   Padrão 39:
#     Tokens: c r i a n ç a _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • criança tomou o grupo chegou
#
#   Padrão 40:
#     Tokens: c r i a n ç a _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • criança tomou o café_da_manhã juntos
#
#   Padrão 41:
#     Tokens: t o m o u _ _ o | | | o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • tomou o café_da_manhã com o
#
#   Padrão 42:
#     Tokens: t o m o u _ _ o | | | o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • tomou o café_da_manhã com cuidado
#
#   Padrão 43:
#     Tokens: t o m o u _ _ o | | | o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • tomou o café_da_manhã fomos caminhar
#
#   Padrão 44:
#     Tokens: t o m o u _ _ o | | | o _ _ c a f é _ d a _ m a n h ã
#     Frases correspondentes:
#       • tomou o café_da_manhã e depois
#
#   Padrão 45:
#     Tokens: o _ _ c a f é _ d a _ m a n h ã | | | c a f é _ d a _ m a n h ã _ _ e
#     Frases correspondentes:
#       • o café_da_manhã e depois estudou
#
#   Padrão 46:
#     Tokens: o _ _ c a f é _ d a _ m a n h ã | | | c a f é _ d a _ m a n h ã _ _ e
#     Frases correspondentes:
#       • o café_da_manhã e tomou o
#
#   Padrão 47:
#     Tokens: c a f é _ d a _ m a n h ã _ _ e | | | e _ _ d e p o i s
#     Frases correspondentes:
#       • café_da_manhã e depois do café_da_manhã
#
#   Padrão 48:
#     Tokens: c a f é _ d a _ m a n h ã _ _ e | | | e _ _ d e p o i s
#     Frases correspondentes:
#       • café_da_manhã e depois estudou matemática
#
#   Padrão 49:
#     Tokens: o _ _ g r u p o | | | g r u p o _ _ c h e g o u
#     Frases correspondentes:
#       • o grupo chegou cedo e
#
#   Padrão 50:
#     Tokens: g r u p o _ _ c h e g o u | | | c h e g o u _ _ c e d o
#     Frases correspondentes:
#       • grupo chegou cedo e tomou
#
#   Padrão 51:
#     Tokens: c h e g o u _ _ c e d o | | | c e d o _ _ e
#     Frases correspondentes:
#       • chegou cedo e depois estudou
#
#   Padrão 52:
#     Tokens: c h e g o u _ _ c e d o | | | c e d o _ _ e
#     Frases correspondentes:
#       • chegou cedo e tomou o
#
#   Padrão 53:
#     Tokens: c e d o _ _ e | | | e _ _ t o m o u
#     Frases correspondentes:
#       • cedo e tomou o café_da_manhã
#
#   Padrão 54:
#     Tokens: e _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • e tomou o cachorro na
#
#   Padrão 55:
#     Tokens: e _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • e tomou o homem preparou
#
#   Padrão 56:
#     Tokens: e _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • e tomou o café_da_manhã com
#
#   Padrão 57:
#     Tokens: e _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • e tomou o café_da_manhã e
#
#   Padrão 58:
#     Tokens: e _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • e tomou o grupo chegou
#
#   Padrão 59:
#     Tokens: e _ _ t o m o u | | | t o m o u _ _ o
#     Frases correspondentes:
#       • e tomou o café_da_manhã juntos
